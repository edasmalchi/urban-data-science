# %% [markdown]
# # SF Open Data Portal
#
# Browse the portal for public datasets: https://data.sfgov.org/
#
# Use Python to retrieve data from the API, just like we learned last week: https://data.sfgov.org/developers
#
# Look at data on bike parking in SF: https://data.sfgov.org/Transportation/Bicycle-Parking-Public-/2e7e-i7me

# %%
import pandas as pd, requests, json, folium

# %%
# use endpoint for bike parking in SF
endpoint_url = 'https://data.sfgov.org/resource/hn4j-6fx5.json'

# open a connection to the URL and download its response
response = requests.get(endpoint_url)

# parse the json string into a Python dict
data = response.json()

# %%
data
# Out:
# [{'install_yr': '2010',
#   'install_mo': '9',
#   'objectid': '647',
#   'address': '1631 OCEAN AVE',
#   'location': 'NCPS',
#   'street': 'OCEAN',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{7337F39A-EBBA-43C1-A5C0-296571D141B7}',
#   'lat': '37.724406',
#   'lon': '-122.459797',
#   'point': {'type': 'Point',
#    'coordinates': [-122.4597967925067, 37.724406010334405]}},
#  {'install_yr': '2004',
#   'install_mo': '0',
#   'objectid': '1960',
#   'address': '3913 24TH ST',
#   'location': 'Savor',
#   'street': '24TH',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{57C56DCE-DE09-462E-B190-0B2A34539F3C}',
#   'lat': '37.751288',
#   'lon': '-122.430024',
#   'point': {'type': 'Point',
#    'coordinates': [-122.43002379492016, 37.75128800595019]}},
#  {'install_yr': '2005',
#   'install_mo': '0',
#   'objectid': '2643',
#   'address': '428 03RD ST',
#   'location': 'Rayko Photo Center',
#   'street': '03RD',
#   'placement': 'SIDEWALK',
#   'racks': '2',
#   'spaces': '4',
#   'globalid': '{90BEBAAB-89ED-4620-8588-6414835E11B3}',
#   'lat': '37.781964',
#   'lon': '-122.397278',
#   'point': {'type': 'Point',
#    'coordinates': [-122.39727779566955, 37.78196400155462]}},
#  {'install_yr': '2004',
#   'install_mo': '0',
#   'objectid': '1108',
#   'address': '265 KING ST',
#   'location': 'Avalon at Mission Bay',
#   'street': 'KING',
#   'placement': 'SIDEWALK',
#   'racks': '3',
#   'spaces': '3',
#   'globalid': '{F76F49F0-E98E-4C69-A14C-6E7CE10D6D76}',
#   'lat': '37.776211',
#   'lon': '-122.393931',
#   'point': {'type': 'Point',
#    'coordinates': [-122.39393079683718, 37.77621100204948]}},
#  {'install_yr': '2016',
#   'install_mo': '8',
#   'objectid': '3391',
#   'address': '1552 polk st',
#   'location': 'Common Sage',
#   'street': 'POLK',
#   'placement': 'SIDEWALK',
#   'racks': '3',
#   'spaces': '6',
#   'globalid': '{E2266A03-A979-48A1-ACF4-6BDEDCAC6B61}',
#   'lat': '37.791074',
#   'lon': '-122.4207',
#   'point': {'type': 'Point',
#    'coordinates': [-122.42070020719177, 37.79107435366886]}},
#  {'install_yr': '2013',
#   'install_mo': '1',
#   'objectid': '2079',
#   'address': '685 MARKET ST',
#   'location': 'La Boulange Cafe & Bakery',
#   'street': 'MARKET',
#   'placement': 'SIDEWALK',
#   'racks': '2',
#   'spaces': '4',
#   'globalid': '{23911432-C558-404B-9789-EA3B3D9CACF4}',
#   'lat': '37.787641',
#   'lon': '-122.402746',
#   'point': {'type': 'Point',
#    'coordinates': [-122.40274579362847, 37.787641001602445]}},
#  {'install_yr': '2003',
#   'install_mo': '0',
#   'objectid': '981',
#   'address': '901 VALENCIA ST',
#   'location': 'La Rondalla Restaurant',
#   'street': '20TH',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{D78A730D-7FA8-4871-A35A-4BBD470AAAA2}',
#   'lat': '37.758346',
#   'lon': '-122.420945',
#   'point': {'type': 'Point',
#    'coordinates': [-122.42094479510453, 37.7583460056493]}},
#  {'install_yr': '2003',
#   'install_mo': '0',
#   'objectid': '1369',
#   'address': '2305 IRVING ST',
#   'location': 'Little Paris',
#   'street': 'IRVING',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{20E6502F-A23E-4679-94C3-C8889DC72FE8}',
#   'lat': '37.763066',
#   'lon': '-122.482629',
#   'point': {'type': 'Point',
#    'coordinates': [-122.48262878556525, 37.76306600919817]}},
#  {'install_yr': '2015',
#   'install_mo': '1',
#   'objectid': '2745',
#   'address': '1811 HAIGHT ST',
#   'location': "Murio's Trophy Room",
#   'street': 'HAIGHT',
#   'placement': 'SIDEWALK',
#   'racks': '2',
#   'spaces': '4',
#   'globalid': '{E8CCB5C6-F3EE-47E1-B7B3-360F3A90C26B}',
#   'lat': '37.769195',
#   'lon': '-122.452167',
#   'point': {'type': 'Point',
#    'coordinates': [-122.45216678865518, 37.76919500700918]}},
#  {'install_yr': '2012',
#   'install_mo': '2',
#   'objectid': '2555',
#   'address': '1799 MCALLISTER ST',
#   'location': 'Matching Half Cafe',
#   'street': 'MCALLISTER',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{5CAD655F-E7B3-40B9-8D10-2C99E7041CF0}',
#   'lat': '37.777213',
#   'lon': '-122.441413',
#   'point': {'type': 'Point',
#    'coordinates': [-122.44141278951774, 37.77721300501366]}},
#  {'install_yr': '2010',
#   'install_mo': '9',
#   'objectid': '117',
#   'address': '9 GROVE ST',
#   'location': 'multiple',
#   'street': 'GROVE',
#   'placement': 'SIDEWALK',
#   'racks': '6',
#   'spaces': '12',
#   'globalid': '{DFBB8EA0-DCCD-456E-B185-E6B985AD94A8}',
#   'lat': '37.778579',
#   'lon': '-122.415428',
#   'point': {'type': 'Point',
#    'coordinates': [-122.41542849364235, 37.77857916376384]}},
#  {'install_yr': '2015',
#   'install_mo': '10',
#   'objectid': '867',
#   'address': '50 FREMONT ST',
#   'location': 'Salesforce',
#   'street': 'FREMONT',
#   'placement': 'SIDEWALK',
#   'racks': '2',
#   'spaces': '4',
#   'globalid': '{43D8B2FD-A7F3-41A1-B904-891FB7E3F198}',
#   'lat': '37.79104',
#   'lon': '-122.397538',
#   'point': {'type': 'Point',
#    'coordinates': [-122.39753837212203, 37.79104012013166]}},
#  {'install_yr': '2010',
#   'install_mo': '10',
#   'objectid': '2482',
#   'address': '3211 MISSION ST',
#   'location': 'Taqueria Can Cun',
#   'street': 'MISSION',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{7A409943-A09E-4A21-8B2F-A31C6EC17028}',
#   'lat': '37.745265',
#   'lon': '-122.419763',
#   'point': {'type': 'Point',
#    'coordinates': [-122.41976279693641, 37.745265006159514]}},
#  {'install_yr': '0',
#   'install_mo': '0',
#   'objectid': '1459',
#   'address': '1351 MCALLISTER ST',
#   'location': 'residential',
#   'street': 'MCALLISTER',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{9DB648DD-7FAB-4E20-AAAE-186B167CC56C}',
#   'lat': '37.778029',
#   'lon': '-122.434194',
#   'point': {'type': 'Point',
#    'coordinates': [-122.43419379040215, 37.77802900443713]}},
#  {'install_yr': '2015',
#   'install_mo': '6',
#   'objectid': '376',
#   'address': '734 LA PLAYA ST',
#   'location': "Kawika's Ocean Beach Deli",
#   'street': 'LA PLAYA',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{D1E4B445-3498-4369-8A70-E5E004D2AE7C}',
#   'lat': '37.774537',
#   'lon': '-122.509945',
#   'point': {'type': 'Point',
#    'coordinates': [-122.50994487937928, 37.77453661068726]}},
#  {'install_yr': '0',
#   'install_mo': '0',
#   'objectid': '826',
#   'address': '603 HAIGHT ST',
#   'location': "Vickie's Boutique",
#   'street': 'HAIGHT',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{E03044A4-E4A9-4A35-B090-A958FDDBB34B}',
#   'lat': '37.771641',
#   'lon': '-122.432203',
#   'point': {'type': 'Point',
#    'coordinates': [-122.4322027920304, 37.77164147441613]}},
#  {'install_yr': '2004',
#   'install_mo': '0',
#   'objectid': '2087',
#   'address': '4780 MISSION ST',
#   'location': 'Burger King',
#   'street': 'MISSION',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{FFF616EB-B7F7-4F6F-ABCF-FAF86F655DA8}',
#   'lat': '37.721698',
#   'lon': '-122.437366',
#   'point': {'type': 'Point',
#    'coordinates': [-122.43736579681219, 37.72169800970371]}},
#  {'install_yr': '2002',
#   'install_mo': '0',
#   'objectid': '568',
#   'address': '3409 24TH ST',
#   'location': 'Papalote',
#   'street': '24TH',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{5B03F2F7-78A8-4563-B112-AA5246F37DD3}',
#   'lat': '37.751935',
#   'lon': '-122.42093',
#   'point': {'type': 'Point',
#    'coordinates': [-122.42092979582175, 37.751935005944404]}},
#  {'install_yr': '2015',
#   'install_mo': '10',
#   'objectid': '1422',
#   'address': '1155 PAGE ST',
#   'location': 'French American School',
#   'street': 'PAGE',
#   'placement': 'SIDEWALK',
#   'racks': '2',
#   'spaces': '4',
#   'globalid': '{5EFAD849-4D4F-485E-A0F0-8C386E964181}',
#   'lat': '37.771807',
#   'lon': '-122.439788',
#   'point': {'type': 'Point',
#    'coordinates': [-122.43978784933384, 37.77180685027034]}},
#  {'install_yr': '2006',
#   'install_mo': '0',
#   'objectid': '2914',
#   'address': '910 MONTGOMERY ST',
#   'location': 'The Purple Onion',
#   'street': 'MONTGOMERY',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{6940DCC9-553C-41FD-A831-E06D697CF240}',
#   'lat': '37.797484',
#   'lon': '-122.403709',
#   'point': {'type': 'Point',
#    'coordinates': [-122.40370879258751, 37.79748400137511]}},
#  {'install_yr': '2013',
#   'install_mo': '11',
#   'objectid': '195',
#   'address': '825 MARKET ST',
#   'location': 'Walgreens',
#   'street': 'MARKET',
#   'placement': 'SIDEWALK',
#   'racks': '2',
#   'spaces': '4',
#   'globalid': '{8038B58D-4615-454B-BCF7-7761B7229133}',
#   'lat': '37.784798',
#   'lon': '-122.406058',
#   'point': {'type': 'Point',
#    'coordinates': [-122.40605759462376, 37.784797692404226]}},
#  {'install_yr': '2010',
#   'install_mo': '11',
#   'objectid': '2328',
#   'address': '525 MARKET ST',
#   'location': 'Chipotle',
#   'street': 'MARKET',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{5FE70BBC-0292-46B4-B77E-9B87FD11C58C}',
#   'lat': '37.790402',
#   'lon': '-122.399263',
#   'point': {'type': 'Point',
#    'coordinates': [-122.39926279490656, 37.7904020007795]}},
#  {'install_yr': '2013',
#   'install_mo': '10',
#   'objectid': '1828',
#   'address': '1520 STOCKTON ST',
#   'location': 'North East Medical Services',
#   'street': 'STOCKTON',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{3B250345-C176-446B-AD5D-62CB0E738BF1}',
#   'lat': '37.799936',
#   'lon': '-122.408712',
#   'point': {'type': 'Point',
#    'coordinates': [-122.4087117916386, 37.79993600085435]}},
#  {'install_yr': '2004',
#   'install_mo': '0',
#   'objectid': '154',
#   'address': '3409 24TH ST',
#   'location': 'Papalote',
#   'street': '24TH',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{54F737B7-C09A-4F3E-AD10-B38F27A1E5C9}',
#   'lat': '37.751935',
#   'lon': '-122.42093',
#   'point': {'type': 'Point',
#    'coordinates': [-122.42092979582175, 37.751935005944404]}},
#  {'install_yr': '2004',
#   'install_mo': '0',
#   'objectid': '2183',
#   'address': '519 LAGUNA ST',
#   'location': 'UNKNOWN',
#   'street': 'LAGUNA',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{4AD9506E-271A-412A-ADED-D9C48C1365E7}',
#   'lat': '37.776091',
#   'lon': '-122.426348',
#   'point': {'type': 'Point',
#    'coordinates': [-122.42634779170794, 37.77609100450785]}},
#  {'install_yr': '2006',
#   'install_mo': '0',
#   'objectid': '1096',
#   'address': '2871 24TH ST',
#   'location': "L'S Caffe",
#   'street': '24TH',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{A1E1520F-C96E-4426-BE63-9AF45015B6CA}',
#   'lat': '37.75254',
#   'lon': '-122.40957',
#   'point': {'type': 'Point',
#    'coordinates': [-122.4095697985142, 37.75254000450096]}},
#  {'install_yr': '2015',
#   'install_mo': '8',
#   'objectid': '452',
#   'address': '1610 BUSH ST',
#   'location': 'Intercultural Institute of California (ICC)',
#   'street': 'BUSH',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{E4C80B70-AD38-4310-AB92-F88100243814}',
#   'lat': '37.788321',
#   'lon': '-122.423815',
#   'point': {'type': 'Point',
#    'coordinates': [-122.42381461515822, 37.78832113560014]}},
#  {'install_yr': '2010',
#   'install_mo': '0',
#   'objectid': '1827',
#   'address': '865 MARKET ST',
#   'location': 'Westfield Centre',
#   'street': 'MARKET',
#   'placement': 'SIDEWALK',
#   'racks': '4',
#   'spaces': '8',
#   'globalid': '{83BD3B13-5284-4048-A6F4-FE20A27D5C97}',
#   'lat': '37.783942',
#   'lon': '-122.407145',
#   'point': {'type': 'Point',
#    'coordinates': [-122.40714479372019, 37.783942002444284]}},
#  {'install_yr': '2003',
#   'install_mo': '0',
#   'objectid': '1414',
#   'address': '451 JUDAH ST',
#   'location': 'Bikram Yoga Inner Sunset',
#   'street': 'JUDAH',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{6D0479BB-C651-4EAA-A089-AA424D09E4C1}',
#   'lat': '37.761884',
#   'lon': '-122.467045',
#   'point': {'type': 'Point',
#    'coordinates': [-122.46704478824225, 37.76188400811002]}},
#  {'install_yr': '2015',
#   'install_mo': '6',
#   'objectid': '2106',
#   'address': '2499 SAN BRUNO AVE',
#   'location': "Breakfast at Tiffany's",
#   'street': 'SAN BRUNO',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{FA5F3B33-FDD2-4718-A5AB-FF61008817F1}',
#   'lat': '37.730494',
#   'lon': '-122.404536',
#   'point': {'type': 'Point',
#    'coordinates': [-122.40453580014535, 37.730493906700985]}},
#  {'install_yr': '2017',
#   'install_mo': '5',
#   'objectid': '3248',
#   'address': '1545 Ocean Ave',
#   'location': 'Medithrive',
#   'street': 'OCEAN',
#   'placement': 'SIDEWALK',
#   'racks': '2',
#   'spaces': '4',
#   'globalid': '{717880A4-6001-445B-879B-704014758D19}',
#   'lat': '37.724322',
#   'lon': '-122.458683',
#   'point': {'type': 'Point',
#    'coordinates': [-122.45868259191829, 37.72432177720126]}},
#  {'install_yr': '2017',
#   'install_mo': '4',
#   'objectid': '3629',
#   'address': '1998 Market Street',
#   'location': 'Direct Urgent Care',
#   'street': 'MARKET',
#   'placement': 'SIDEWALK',
#   'racks': '4',
#   'spaces': '8',
#   'globalid': '{14612462-4BE3-418D-81A0-B3A2336A64B8}',
#   'lat': '37.769775',
#   'lon': '-122.426399',
#   'point': {'type': 'Point',
#    'coordinates': [-122.42639862939353, 37.76977531614113]}},
#  {'install_yr': '2010',
#   'install_mo': '7',
#   'objectid': '216',
#   'address': '580 DUBOCE AVE',
#   'location': 'Duboce Park',
#   'street': 'DUBOCE',
#   'placement': 'SIDEWALK',
#   'racks': '2',
#   'spaces': '4',
#   'globalid': '{92883029-EA2A-4F59-BF0E-7138F539028D}',
#   'lat': '37.769243',
#   'lon': '-122.4327',
#   'point': {'type': 'Point',
#    'coordinates': [-122.43269979178346, 37.769243005250246]}},
#  {'install_yr': '2002',
#   'install_mo': '0',
#   'objectid': '1334',
#   'address': '3318 24TH ST',
#   'location': 'Cafe La Boheme',
#   'street': '24TH',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{B88389F0-1560-44A1-8B04-9C3EDE34636A}',
#   'lat': '37.752394',
#   'lon': '-122.418791',
#   'point': {'type': 'Point',
#    'coordinates': [-122.41879079647241, 37.75239400592727]}},
#  {'install_yr': '2017',
#   'install_mo': '5',
#   'objectid': '3230',
#   'address': '327 Divisidero St',
#   'location': 'SALT',
#   'street': 'DIVISADERO',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{94EC1445-8F87-498C-9FE4-B9D81F318D20}',
#   'lat': '37.772443',
#   'lon': '-122.43742',
#   'point': {'type': 'Point',
#    'coordinates': [-122.43741960832456, 37.77244267877765]}},
#  {'install_yr': '2015',
#   'install_mo': '10',
#   'objectid': '852',
#   'address': '119 07TH ST',
#   'location': '6th on 7th Gallery',
#   'street': '07TH',
#   'placement': 'SIDEWALK',
#   'racks': '2',
#   'spaces': '4',
#   'globalid': '{A451B623-E2CC-4CB6-B9C4-E952B832B157}',
#   'lat': '37.778847',
#   'lon': '-122.410356',
#   'point': {'type': 'Point',
#    'coordinates': [-122.41035626115678, 37.778846618374935]}},
#  {'install_yr': '2015',
#   'install_mo': '11',
#   'objectid': '2348',
#   'address': '240 POWELL ST',
#   'location': 'LUSH Handmade Cosmetics',
#   'street': 'POWELL',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{4916BC36-796D-4EA9-92C4-832648971932}',
#   'lat': '37.786813',
#   'lon': '-122.40803',
#   'point': {'type': 'Point',
#    'coordinates': [-122.40802959943684, 37.78681325166725]}},
#  {'install_yr': '2003',
#   'install_mo': '0',
#   'objectid': '2334',
#   'address': '2325 NORIEGA ST',
#   'location': 'UNKNOWN',
#   'street': 'NORIEGA',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{ED3680C2-49EB-4CB6-A8E6-213C588D803E}',
#   'lat': '37.753437',
#   'lon': '-122.48878',
#   'point': {'type': 'Point',
#    'coordinates': [-122.48877978561298, 37.75343700991319]}},
#  {'install_yr': '2010',
#   'install_mo': '11',
#   'objectid': '409',
#   'address': '59 GRANT AVE',
#   'location': 'Sisley',
#   'street': 'GRANT',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{78B95E00-C8F6-403F-A9D7-61ED04103CDD}',
#   'lat': '37.787515',
#   'lon': '-122.405251',
#   'point': {'type': 'Point',
#    'coordinates': [-122.40525079441454, 37.78751500161387]}},
#  {'install_yr': '2005',
#   'install_mo': '0',
#   'objectid': '1937',
#   'address': '670 SOUTH VAN NESS AVE',
#   'location': 'FatChanceBellyDance',
#   'street': 'SOUTH VAN NESS',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{69600D73-7724-41C7-A105-EDDB8F2A0C2D}',
#   'lat': '37.762413',
#   'lon': '-122.417565',
#   'point': {'type': 'Point',
#    'coordinates': [-122.4175647957601, 37.76241300480122]}},
#  {'install_yr': '2017',
#   'install_mo': '2',
#   'objectid': '3312',
#   'address': '4734 03rd Street',
#   'location': 'Trifusion Yoga',
#   'street': '03RD',
#   'placement': 'SIDEWALK',
#   'racks': '2',
#   'spaces': '4',
#   'globalid': '{DB869063-557A-4912-BF37-96D01217DAE2}',
#   'lat': '37.735346',
#   'lon': '-122.390662',
#   'point': {'type': 'Point',
#    'coordinates': [-122.39066239800412, 37.735346213713925]}},
#  {'install_yr': '2006',
#   'install_mo': '0',
#   'objectid': '1028',
#   'address': '2125 POWELL ST',
#   'location': 'UNKNOWN',
#   'street': 'POWELL',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{9D4B344D-63C0-485C-8336-8B2BBC29B7FE}',
#   'lat': '37.804343',
#   'lon': '-122.411884',
#   'point': {'type': 'Point',
#    'coordinates': [-122.41188379080302, 37.804343000024794]}},
#  {'install_yr': '2010',
#   'install_mo': '0',
#   'objectid': '1373',
#   'address': '630 IRVING ST',
#   'location': 'residential',
#   'street': 'IRVING',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{03F8462A-8EF1-4522-ACD2-8C9E0942BE02}',
#   'lat': '37.76435',
#   'lon': '-122.464757',
#   'point': {'type': 'Point',
#    'coordinates': [-122.46475678826363, 37.764350007893384]}},
#  {'install_yr': '2004',
#   'install_mo': '0',
#   'objectid': '2236',
#   'address': '399 GROVE ST',
#   'location': 'Boxing Room',
#   'street': 'GROVE',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{20B887B5-073D-49FF-9C4A-C8624E9B54F7}',
#   'lat': '37.777599',
#   'lon': '-122.422751',
#   'point': {'type': 'Point',
#    'coordinates': [-122.42275079281046, 37.777599003334025]}},
#  {'install_yr': '2010',
#   'install_mo': '0',
#   'objectid': '1174',
#   'address': '1881 POST ST',
#   'location': 'Kabuki Sundance Cinema',
#   'street': 'POST',
#   'placement': 'SIDEWALK',
#   'racks': '3',
#   'spaces': '6',
#   'globalid': '{6A33F93B-79AB-4A74-BD7F-0C4E8BAF72F9}',
#   'lat': '37.784916',
#   'lon': '-122.432279',
#   'point': {'type': 'Point',
#    'coordinates': [-122.4322787905578, 37.78491600460156]}},
#  {'install_yr': '2003',
#   'install_mo': '0',
#   'objectid': '2619',
#   'address': '3602 20TH ST',
#   'location': 'Ruby',
#   'street': '20TH',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{97929634-38BD-4B77-ADC0-5B59E8DD1FA6}',
#   'lat': '37.758701',
#   'lon': '-122.421595',
#   'point': {'type': 'Point',
#    'coordinates': [-122.4215948950153, 37.7587009946928]}},
#  {'install_yr': '2005',
#   'install_mo': '0',
#   'objectid': '1143',
#   'address': '520 SCOTT ST',
#   'location': 'UNKNOWN',
#   'street': 'SCOTT',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{CA185E0F-636D-47C9-845B-FEBD115AFF7A}',
#   'lat': '37.77462',
#   'lon': '-122.435702',
#   'point': {'type': 'Point',
#    'coordinates': [-122.4357017918266, 37.774620005397345]}},
#  {'install_yr': '2012',
#   'install_mo': '2',
#   'objectid': '1449',
#   'address': '1028 POTRERO AVE',
#   'location': 'La Paz Restaurant',
#   'street': 'POTRERO',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{FD111C06-B228-40DF-B337-6ED68ADE542E}',
#   'lat': '37.755605',
#   'lon': '-122.406916',
#   'point': {'type': 'Point',
#    'coordinates': [-122.4069157974405, 37.75560500429468]}},
#  {'install_yr': '2002',
#   'install_mo': '0',
#   'objectid': '2787',
#   'address': '448 CORTLAND AVE',
#   'location': 'Good Life Grocery',
#   'street': 'CORTLAND',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{EA81965F-8E2B-482D-AA96-DC76413CE9A7}',
#   'lat': '37.738888',
#   'lon': '-122.416705',
#   'point': {'type': 'Point',
#    'coordinates': [-122.41670479745056, 37.73888800665771]}},
#  {'install_yr': '2002',
#   'install_mo': '0',
#   'objectid': '112',
#   'address': '780 STANYAN ST',
#   'location': 'Yoga Tree',
#   'street': 'STANYAN',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{E381BCD5-1B47-4ABF-AA2C-48C8775BB3AD}',
#   'lat': '37.767778',
#   'lon': '-122.452869',
#   'point': {'type': 'Point',
#    'coordinates': [-122.45286878993328, 37.7677780064895]}},
#  {'install_yr': '2010',
#   'install_mo': '0',
#   'objectid': '192',
#   'address': '1899 IRVING ST',
#   'location': 'Lucca Foods',
#   'street': 'IRVING',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{F66A3FC0-85ED-43B0-94C2-ACDADA8A8498}',
#   'lat': '37.763277',
#   'lon': '-122.477909',
#   'point': {'type': 'Point',
#    'coordinates': [-122.47790898620603, 37.763276699018775]}},
#  {'install_yr': '2003',
#   'install_mo': '0',
#   'objectid': '1420',
#   'address': '3388 17TH ST',
#   'location': 'Core Pilates',
#   'street': '17TH',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{70452FDA-C754-4894-9192-1E66E6ACC145}',
#   'lat': '37.763572',
#   'lon': '-122.421023',
#   'point': {'type': 'Point',
#    'coordinates': [-122.42102279461311, 37.763572004561716]}},
#  {'install_yr': '2014',
#   'install_mo': '12',
#   'objectid': '1990',
#   'address': '200 COLUMBUS AVE',
#   'location': 'Reveille Coffee',
#   'street': 'KEARNY',
#   'placement': 'ROADWAY',
#   'racks': '5',
#   'spaces': '10',
#   'globalid': '{FDC6C40F-8DFE-45ED-BA5C-E847EF03B167}',
#   'lat': '37.797355',
#   'lon': '-122.405547',
#   'point': {'type': 'Point',
#    'coordinates': [-122.40554679329645, 37.79735500153817]}},
#  {'install_yr': '2015',
#   'install_mo': '1',
#   'objectid': '1572',
#   'address': '4754 MISSION ST',
#   'location': 'Mama Art Cafe',
#   'street': 'MISSION',
#   'placement': 'SIDEWALK',
#   'racks': '2',
#   'spaces': '4',
#   'globalid': '{A04D462E-CDD5-4268-96B8-A10749A1A5FB}',
#   'lat': '37.722067',
#   'lon': '-122.437102',
#   'point': {'type': 'Point',
#    'coordinates': [-122.43710219652485, 37.722067408693036]}},
#  {'install_yr': '2003',
#   'install_mo': '0',
#   'objectid': '245',
#   'address': '333 BUSH ST',
#   'location': 'office building',
#   'street': 'BUSH',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{AFBB52DF-73B2-4583-B05A-721E64C38D66}',
#   'lat': '37.790587',
#   'lon': '-122.403044',
#   'point': {'type': 'Point',
#    'coordinates': [-122.4030437940648, 37.79058700098888]}},
#  {'install_yr': '2013',
#   'install_mo': '1',
#   'objectid': '1066',
#   'address': '2 SANCHEZ ST',
#   'location': 'Duboce Park Cafe',
#   'street': 'SANCHEZ',
#   'placement': 'SIDEWALK',
#   'racks': '3',
#   'spaces': '6',
#   'globalid': '{8CA617FE-2977-40A4-A723-E38EC339B2A9}',
#   'lat': '37.769156',
#   'lon': '-122.43161',
#   'point': {'type': 'Point',
#    'coordinates': [-122.43160979253891, 37.769156004901774]}},
#  {'install_yr': '2002',
#   'install_mo': '0',
#   'objectid': '324',
#   'address': '111 ELLIS ST',
#   'location': 'Rasputin Music',
#   'street': 'ELLIS',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{9EF36A08-3851-48F7-9E24-603AB44521F8}',
#   'lat': '37.785301',
#   'lon': '-122.408054',
#   'point': {'type': 'Point',
#    'coordinates': [-122.40805379481449, 37.78530100209957]}},
#  {'install_yr': '2004',
#   'install_mo': '0',
#   'objectid': '2841',
#   'address': '2295 HARRISON ST',
#   'location': 'Mission Cliffs',
#   'street': 'HARRISON',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{BE7491AF-6B98-492A-BBD5-0194B409B510}',
#   'lat': '37.760911',
#   'lon': '-122.412321',
#   'point': {'type': 'Point',
#    'coordinates': [-122.41232079604241, 37.76091100369296]}},
#  {'install_yr': '2002',
#   'install_mo': '0',
#   'objectid': '2899',
#   'address': '500 DE HARO ST',
#   'location': "St Gregory's Church",
#   'street': 'DE HARO',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{13FBC22A-999D-4B28-B317-9E2AEEE9AAE3}',
#   'lat': '37.763346',
#   'lon': '-122.401762',
#   'point': {'type': 'Point',
#    'coordinates': [-122.4017619970421, 37.76334550299934]}},
#  {'install_yr': '2010',
#   'install_mo': '0',
#   'objectid': '628',
#   'address': '588 HAIGHT ST',
#   'location': "O'Looney's Market",
#   'street': 'HAIGHT',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{E2E5246F-D73B-445B-B30D-E9F4D4D243BF}',
#   'lat': '37.772161',
#   'lon': '-122.431864',
#   'point': {'type': 'Point',
#    'coordinates': [-122.43186379119669, 37.77216100441219]}},
#  {'install_yr': '2014',
#   'install_mo': '12',
#   'objectid': '863',
#   'address': '666 CHENERY ST',
#   'location': 'fitGLENfit',
#   'street': 'CHENERY',
#   'placement': 'ROADWAY',
#   'racks': '5',
#   'spaces': '10',
#   'globalid': '{4F203DBD-A84B-4DF2-A3E4-A28AF501A93A}',
#   'lat': '37.73476',
#   'lon': '-122.433428',
#   'point': {'type': 'Point',
#    'coordinates': [-122.4334277957203, 37.73476000799334]}},
#  {'install_yr': '2016',
#   'install_mo': '8',
#   'objectid': '3417',
#   'address': '1314 Noriega',
#   'location': 'bb tea',
#   'street': 'NORIEGA',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{2BD30C40-C43B-49C6-ADFF-2A8816E7BD02}',
#   'lat': '37.754254',
#   'lon': '-122.477729',
#   'point': {'type': 'Point',
#    'coordinates': [-122.47772861112433, 37.75425355333447]}},
#  {'install_yr': '2002',
#   'install_mo': '0',
#   'objectid': '2201',
#   'address': '1017 MARKET ST',
#   'location': 'UNKNOWN',
#   'street': 'MARKET',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{CEEBA6D5-848B-494E-B006-B2FEF125D15A}',
#   'lat': '37.781556',
#   'lon': '-122.410405',
#   'point': {'type': 'Point',
#    'coordinates': [-122.41040479427046, 37.7815560029888]}},
#  {'install_yr': '2015',
#   'install_mo': '6',
#   'objectid': '96',
#   'address': '165 GRATTAN ST',
#   'location': 'Grattan Elementary School',
#   'street': 'GRATTAN',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{A8BD8A37-B401-4B09-B7B7-10F822742E5B}',
#   'lat': '37.763626',
#   'lon': '-122.450467',
#   'point': {'type': 'Point',
#    'coordinates': [-122.45046709060604, 37.76362590721044]}},
#  {'install_yr': '2003',
#   'install_mo': '0',
#   'objectid': '2921',
#   'address': '1640 STOCKTON ST',
#   'location': 'UNKNOWN',
#   'street': 'STOCKTON',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{01C6EFD2-DAFA-45F2-8031-EC6DEAEECEF2}',
#   'lat': '37.801005',
#   'lon': '-122.408928',
#   'point': {'type': 'Point',
#    'coordinates': [-122.40892779274999, 37.80100500122363]}},
#  {'install_yr': '2003',
#   'install_mo': '0',
#   'objectid': '897',
#   'address': '595 BUCKINGHAM WAY',
#   'location': 'medical building',
#   'street': 'BUCKINGHAM',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{8588E0D4-2F0D-46EA-A8A2-263AD5092ED0}',
#   'lat': '37.729519',
#   'lon': '-122.479506',
#   'point': {'type': 'Point',
#    'coordinates': [-122.47950578970118, 37.72951901185783]}},
#  {'install_yr': '2011',
#   'install_mo': '0',
#   'objectid': '2999',
#   'address': '1801 GREEN ST',
#   'location': 'Golden Gate Valley Branch Library',
#   'street': 'GREEN',
#   'placement': 'SIDEWALK',
#   'racks': '7',
#   'spaces': '14',
#   'globalid': '{DEAD1EF0-78B2-4A47-AE23-4032C25B954A}',
#   'lat': '37.796784',
#   'lon': '-122.42901',
#   'point': {'type': 'Point',
#    'coordinates': [-122.42900979034819, 37.7967840027592]}},
#  {'install_yr': '2015',
#   'install_mo': '7',
#   'objectid': '1407',
#   'address': '354 05TH ST',
#   'location': 'Wood Thumb',
#   'street': '05TH',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{284C2606-FD0D-44C6-9D71-F04979889B34}',
#   'lat': '37.779459',
#   'lon': '-122.402739',
#   'point': {'type': 'Point',
#    'coordinates': [-122.40273899494053, 37.77945940184289]}},
#  {'install_yr': '2013',
#   'install_mo': '8',
#   'objectid': '1911',
#   'address': '2211 MISSION ST',
#   'location': 'Gracias Madre',
#   'street': 'MISSION',
#   'placement': 'ROADWAY',
#   'racks': '4',
#   'spaces': '8',
#   'globalid': '{6ABC3DD4-6EDE-4F9F-A34F-A61143752B19}',
#   'lat': '37.761544',
#   'lon': '-122.418963',
#   'point': {'type': 'Point',
#    'coordinates': [-122.41896279530725, 37.76154400472919]}},
#  {'install_yr': '2004',
#   'install_mo': '0',
#   'objectid': '2884',
#   'address': '101 UTAH ST',
#   'location': 'Oceanic Restaurant',
#   'street': 'UTAH',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{A15D2B36-5116-46AA-9FA4-DC8BBA973D25}',
#   'lat': '37.767877',
#   'lon': '-122.406298',
#   'point': {'type': 'Point',
#    'coordinates': [-122.40629779589665, 37.76787700356809]}},
#  {'install_yr': '2005',
#   'install_mo': '0',
#   'objectid': '1117',
#   'address': '578 MARKET ST',
#   'location': "Quizno's",
#   'street': 'MARKET',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{F8CA8DC4-0709-4CA1-88A6-59D6229F59FC}',
#   'lat': '37.789635',
#   'lon': '-122.401435',
#   'point': {'type': 'Point',
#    'coordinates': [-122.40143479453255, 37.78963500121104]}},
#  {'install_yr': '2005',
#   'install_mo': '0',
#   'objectid': '1852',
#   'address': '1300 DOLORES ST',
#   'location': 'Luv A Java',
#   'street': '26TH',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{1B573F1B-E6EB-452D-88D4-6C3747AB5D6B}',
#   'lat': '37.748485',
#   'lon': '-122.425163',
#   'point': {'type': 'Point',
#    'coordinates': [-122.42516279580215, 37.74848500674723]}},
#  {'install_yr': '2004',
#   'install_mo': '0',
#   'objectid': '421',
#   'address': '3801 SACRAMENTO ST',
#   'location': 'UNKNOWN',
#   'street': 'SACRAMENTO',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{3119D513-0718-48CA-858A-9E25F0CACA2A}',
#   'lat': '37.786824',
#   'lon': '-122.455435',
#   'point': {'type': 'Point',
#    'coordinates': [-122.45543478670768, 37.78682400517625]}},
#  {'install_yr': '2009',
#   'install_mo': '0',
#   'objectid': '1469',
#   'address': '57 LELAND AVE',
#   'location': 'Visiticion Chinese Baptist Church',
#   'street': 'LELAND',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{7E346224-DDD6-481F-B5C6-149550C3F655}',
#   'lat': '37.711497',
#   'lon': '-122.405139',
#   'point': {'type': 'Point',
#    'coordinates': [-122.40513880314253, 37.71149700815447]}},
#  {'install_yr': '2010',
#   'install_mo': '11',
#   'objectid': '2475',
#   'address': '600 OCTAVIA ST',
#   'location': 'Seesaw LLC Cafe',
#   'street': 'OCTAVIA',
#   'placement': 'SIDEWALK',
#   'racks': '2',
#   'spaces': '4',
#   'globalid': '{8D30D1A1-2AF1-45C5-AD0F-75B320505BE9}',
#   'lat': '37.777808',
#   'lon': '-122.42467',
#   'point': {'type': 'Point',
#    'coordinates': [-122.42466979151502, 37.77780800398159]}},
#  {'install_yr': '2017',
#   'install_mo': '5',
#   'objectid': '3259',
#   'address': '3440 Geary Blvd',
#   'location': 'Panchos Salsa Bar and Grill',
#   'street': 'GEARY',
#   'placement': 'SIDEWALK',
#   'racks': '2',
#   'spaces': '4',
#   'globalid': '{CB9C199D-D395-4A4A-828F-88BBE1954086}',
#   'lat': '37.781525',
#   'lon': '-122.456191',
#   'point': {'type': 'Point',
#    'coordinates': [-122.45619109099658, 37.781525369934464]}},
#  {'install_yr': '2015',
#   'install_mo': '10',
#   'objectid': '1186',
#   'address': '255 KANSAS ST',
#   'location': '16th & Kansas Streets Building LLC',
#   'street': 'KANSAS',
#   'placement': 'SIDEWALK',
#   'racks': '2',
#   'spaces': '4',
#   'globalid': '{12376FD9-660F-486C-8353-F7F647BAEAD2}',
#   'lat': '37.766609',
#   'lon': '-122.403609',
#   'point': {'type': 'Point',
#    'coordinates': [-122.40360943880944, 37.76660927738789]}},
#  {'install_yr': '2016',
#   'install_mo': '8',
#   'objectid': '3422',
#   'address': '2407 Noriega',
#   'location': 'dental health of sf',
#   'street': 'NORIEGA',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{46E85221-DB3D-479E-B982-A93B4AC9C8ED}',
#   'lat': '37.753601',
#   'lon': '-122.489413',
#   'point': {'type': 'Point',
#    'coordinates': [-122.4894132011007, 37.75360148374934]}},
#  {'install_yr': '2013',
#   'install_mo': '7',
#   'objectid': '800',
#   'address': '327 GRANT AVE',
#   'location': 'lululemon athletica',
#   'street': 'GRANT',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{AC942795-9D6C-475B-8251-A5F75330AD63}',
#   'lat': '37.790145',
#   'lon': '-122.405857',
#   'point': {'type': 'Point',
#    'coordinates': [-122.40585679362997, 37.79014500137277]}},
#  {'install_yr': '2017',
#   'install_mo': '5',
#   'objectid': '3240',
#   'address': '1408 Clement St',
#   'location': 'Heartbaker',
#   'street': 'CLEMENT',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{A93B5288-7B37-4FB2-A73C-901B809681A6}',
#   'lat': '37.782572',
#   'lon': '-122.474236',
#   'point': {'type': 'Point',
#    'coordinates': [-122.47423568389134, 37.7825720924424]}},
#  {'install_yr': '2015',
#   'install_mo': '1',
#   'objectid': '2683',
#   'address': '499 BAY ST',
#   'location': 'Starbucks',
#   'street': 'TAYLOR',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{5DEC3D24-07BD-4831-969E-98BB9CA6703C}',
#   'lat': '37.80532',
#   'lon': '-122.415084',
#   'point': {'type': 'Point',
#    'coordinates': [-122.41508399092557, 37.80532010077332]}},
#  {'install_yr': '2013',
#   'install_mo': '3',
#   'objectid': '879',
#   'address': '130 WEST PORTAL AVE',
#   'location': 'Citibank',
#   'street': 'WEST PORTAL',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{071F92A0-87AA-4B88-97B5-ECA662E193A3}',
#   'lat': '37.739482',
#   'lon': '-122.467739',
#   'point': {'type': 'Point',
#    'coordinates': [-122.46773879028596, 37.739482009615685]}},
#  {'install_yr': '2010',
#   'install_mo': '7',
#   'objectid': '559',
#   'address': '3349 20TH ST',
#   'location': 'Shotwells',
#   'street': '20TH',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{CFA2C2E2-7607-43DA-92AE-6357DF90D8AF}',
#   'lat': '37.758616',
#   'lon': '-122.415599',
#   'point': {'type': 'Point',
#    'coordinates': [-122.41559879576401, 37.7586160050358]}},
#  {'install_yr': '2016',
#   'install_mo': '8',
#   'objectid': '3429',
#   'address': '1396 La Playa St',
#   'location': 'java beach cafe',
#   'street': 'LA PLAYA',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{47087EF1-9C9D-401F-A545-43D6F72A2CD1}',
#   'lat': '37.760378',
#   'lon': '-122.509061',
#   'point': {'type': 'Point',
#    'coordinates': [-122.5090611574199, 37.760377572962945]}},
#  {'install_yr': '2002',
#   'install_mo': '0',
#   'objectid': '2820',
#   'address': '3870 24TH ST',
#   'location': 'Ladybug Ladybug',
#   'street': '24TH',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{B804B6C2-D360-4A9E-8920-22ADB2AF81E7}',
#   'lat': '37.751837',
#   'lon': '-122.429044',
#   'point': {'type': 'Point',
#    'coordinates': [-122.42904379449185, 37.751837005924926]}},
#  {'install_yr': '2013',
#   'install_mo': '9',
#   'objectid': '2517',
#   'address': '4304 18TH ST',
#   'location': 'US Post Office',
#   'street': '18TH',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{C615E0FB-3E2D-4A98-85B2-80F8B950EED9}',
#   'lat': '37.76093',
#   'lon': '-122.437392',
#   'point': {'type': 'Point',
#    'coordinates': [-122.43739179243671, 37.76093000656166]}},
#  {'install_yr': '2002',
#   'install_mo': '0',
#   'objectid': '85',
#   'address': '801 PORTOLA DR',
#   'location': 'medical building',
#   'street': 'PORTOLA',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{8E7CC811-4340-4F13-BA01-358EB61D13C6}',
#   'lat': '37.743618',
#   'lon': '-122.454079',
#   'point': {'type': 'Point',
#    'coordinates': [-122.45407879145293, 37.743618008489825]}},
#  {'install_yr': '2004',
#   'install_mo': '0',
#   'objectid': '1446',
#   'address': '828 HOLLOWAY AVE',
#   'location': 'Touch of Heaven',
#   'street': 'HOLLOWAY',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{A7778D8E-7044-4ECA-AC70-CFB8D93AE6EE}',
#   'lat': '37.722047',
#   'lon': '-122.461614',
#   'point': {'type': 'Point',
#    'coordinates': [-122.46161379288529, 37.72204706141811]}},
#  {'install_yr': '2011',
#   'install_mo': '5',
#   'objectid': '2169',
#   'address': '979 MARKET ST',
#   'location': 'Blick Arts Materials',
#   'street': 'MARKET',
#   'placement': 'SIDEWALK',
#   'racks': '2',
#   'spaces': '4',
#   'globalid': '{9BD715EF-378C-4899-9275-0110BB29CF4E}',
#   'lat': '37.782276',
#   'lon': '-122.409518',
#   'point': {'type': 'Point',
#    'coordinates': [-122.40951779403193, 37.782276001976626]}},
#  {'install_yr': '2012',
#   'install_mo': '4',
#   'objectid': '1793',
#   'address': '600 THE EMBARCADERO',
#   'location': 'Delancy Street Restaurant',
#   'street': 'EMBARCADERO',
#   'placement': 'SIDEWALK',
#   'racks': '2',
#   'spaces': '4',
#   'globalid': '{F0395018-B93B-4A70-AA1B-109FD574534D}',
#   'lat': '37.783481',
#   'lon': '-122.38888',
#   'point': {'type': 'Point',
#    'coordinates': [-122.38887979758361, 37.78348100147626]}},
#  {'install_yr': '2006',
#   'install_mo': '0',
#   'objectid': '814',
#   'address': '3566 SACRAMENTO ST',
#   'location': 'UNKNOWN',
#   'street': 'SACRAMENTO',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{13DD7850-B729-4ED9-9ADF-19F09F20F605}',
#   'lat': '37.787726',
#   'lon': '-122.451485',
#   'point': {'type': 'Point',
#    'coordinates': [-122.45148478711418, 37.78772600498085]}},
#  {'install_yr': '2006',
#   'install_mo': '0',
#   'objectid': '1098',
#   'address': '628 DIVISADERO ST',
#   'location': 'The Independent',
#   'street': 'DIVISADERO',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{67C73657-D6E1-4595-B158-50DA70654E17}',
#   'lat': '37.775528',
#   'lon': '-122.437497',
#   'point': {'type': 'Point',
#    'coordinates': [-122.43749679143265, 37.77552800459286]}},
#  {'install_yr': '2017',
#   'install_mo': '3',
#   'objectid': '3623',
#   'address': '2298 Market Street',
#   'location': 'Café Flore',
#   'street': 'MARKET',
#   'placement': 'ROADWAY',
#   'racks': '10',
#   'spaces': '20',
#   'globalid': '{5DD19A80-3E9E-4442-B813-6FA4BA991790}',
#   'lat': '37.764288',
#   'lon': '-122.433118',
#   'point': {'type': 'Point',
#    'coordinates': [-122.43311750998788, 37.76428829063609]}},
#  {'install_yr': '2002',
#   'install_mo': '0',
#   'objectid': '28',
#   'address': '2041 MARKET ST',
#   'location': 'salon baobao',
#   'street': 'MARKET',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{166F318F-739D-48AD-8CF4-BB9D772985B3}',
#   'lat': '37.768188',
#   'lon': '-122.427514',
#   'point': {'type': 'Point',
#    'coordinates': [-122.42751379276855, 37.76818800457095]}},
#  {'install_yr': '2009',
#   'install_mo': '0',
#   'objectid': '2140',
#   'address': '110 LELAND AVE',
#   'location': 'Luen Fat Bakery',
#   'street': 'LELAND',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{20D708B3-0D73-4D29-B7B5-231F6EDFE9D4}',
#   'lat': '37.712232',
#   'lon': '-122.405769',
#   'point': {'type': 'Point',
#    'coordinates': [-122.40576880267147, 37.71223200755259]}},
#  {'install_yr': '2003',
#   'install_mo': '0',
#   'objectid': '1826',
#   'address': '200 FOLSOM ST',
#   'location': 'UNKNOWN',
#   'street': 'FOLSOM',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{EAD0CD15-A7FF-4942-BEEE-2789E5B98313}',
#   'lat': '37.789281',
#   'lon': '-122.392286',
#   'point': {'type': 'Point',
#    'coordinates': [-122.39228579587503, 37.789281000599374]}},
#  {'install_yr': '2015',
#   'install_mo': '1',
#   'objectid': '1964',
#   'address': '4567 MISSION ST',
#   'location': 'Jupiter Market',
#   'street': 'MISSION',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{4563BB11-34CF-4839-BF4D-85789C9FA5D0}',
#   'lat': '37.725058',
#   'lon': '-122.434092',
#   'point': {'type': 'Point',
#    'coordinates': [-122.43409229679507, 37.72505770886877]}},
#  {'install_yr': '2011',
#   'install_mo': '4',
#   'objectid': '1229',
#   'address': '904 22ND ST',
#   'location': 'Rickshaw Bagworks',
#   'street': '22ND',
#   'placement': 'SIDEWALK',
#   'racks': '2',
#   'spaces': '4',
#   'globalid': '{5B78C652-072D-4694-938B-5DF9BADC5ACD}',
#   'lat': '37.758027',
#   'lon': '-122.390572',
#   'point': {'type': 'Point',
#    'coordinates': [-122.39057179977046, 37.758027002705276]}},
#  {'install_yr': '2002',
#   'install_mo': '0',
#   'objectid': '2171',
#   'address': '2282 MARKET ST',
#   'location': 'UNKNOWN',
#   'street': 'MARKET',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{BFC3BF94-D80A-4540-9AF0-30C3E33EFCBC}',
#   'lat': '37.764885',
#   'lon': '-122.432814',
#   'point': {'type': 'Point',
#    'coordinates': [-122.4328137928782, 37.764885006139565]}},
#  {'install_yr': '2012',
#   'install_mo': '8',
#   'objectid': '1064',
#   'address': '2 CLEMENT ST',
#   'location': 'Clement Mini Mart',
#   'street': 'CLEMENT',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{C95FC187-551E-4DED-9A48-917BD63ADC4C}',
#   'lat': '37.783403',
#   'lon': '-122.459286',
#   'point': {'type': 'Point',
#    'coordinates': [-122.45928648630907, 37.78340249524902]}},
#  {'install_yr': '2002',
#   'install_mo': '0',
#   'objectid': '2543',
#   'address': '1551 DOLORES ST',
#   'location': 'Noeteca',
#   'street': 'DOLORES',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{C21D8784-146C-445E-A31E-2C4DD6CB822C}',
#   'lat': '37.744531',
#   'lon': '-122.424058',
#   'point': {'type': 'Point',
#    'coordinates': [-122.42405779619729, 37.744531006635476]}},
#  {'install_yr': '2004',
#   'install_mo': '0',
#   'objectid': '182',
#   'address': '400 VALENCIA ST',
#   'location': 'Little Star Pizza',
#   'street': 'VALENCIA',
#   'placement': 'SIDEWALK',
#   'racks': '2',
#   'spaces': '4',
#   'globalid': '{78AD1E2B-E16F-4708-BC01-8563204C075C}',
#   'lat': '37.766373',
#   'lon': '-122.4224',
#   'point': {'type': 'Point',
#    'coordinates': [-122.42239979428139, 37.766373004692085]}},
#  {'install_yr': '0',
#   'install_mo': '0',
#   'objectid': '1627',
#   'address': '2501 MARIPOSA ST',
#   'location': 'Slow Club',
#   'street': 'MARIPOSA',
#   'placement': 'SIDEWALK',
#   'racks': '2',
#   'spaces': '4',
#   'globalid': '{FDD84C78-348B-4B0D-900E-1FAFB4E8320C}',
#   'lat': '37.762776',
#   'lon': '-122.408536',
#   'point': {'type': 'Point',
#    'coordinates': [-122.4085357960936, 37.76277600409595]}},
#  {'install_yr': '2003',
#   'install_mo': '0',
#   'objectid': '2965',
#   'address': '3141 17TH ST',
#   'location': 'Ocean Sash and Door Co.',
#   'street': '17TH',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{7CACF273-FA34-4A5F-AFCA-E5CE12B8EB58}',
#   'lat': '37.763409',
#   'lon': '-122.416016',
#   'point': {'type': 'Point',
#    'coordinates': [-122.41601579520176, 37.763409004318575]}},
#  {'install_yr': '2012',
#   'install_mo': '11',
#   'objectid': '300',
#   'address': '448 CORTLAND AVE',
#   'location': 'Good Life Grocery',
#   'street': 'CORTLAND',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{C2E4C1C4-604A-41D9-8CA7-ACE1328537CE}',
#   'lat': '37.738888',
#   'lon': '-122.416705',
#   'point': {'type': 'Point',
#    'coordinates': [-122.41670479745056, 37.73888800665771]}},
#  {'install_yr': '2011',
#   'install_mo': '6',
#   'objectid': '1352',
#   'address': '750 16TH AVE',
#   'location': 'Argonne Community Garden',
#   'street': '16TH',
#   'placement': 'SIDEWALK',
#   'racks': '2',
#   'spaces': '4',
#   'globalid': '{543E92C7-397F-46A5-A435-C9EDC639902B}',
#   'lat': '37.773964',
#   'lon': '-122.474044',
#   'point': {'type': 'Point',
#    'coordinates': [-122.47404378491176, 37.77396400740777]}},
#  {'install_yr': '2015',
#   'install_mo': '12',
#   'objectid': '1251',
#   'address': '1145 FOLSOM ST',
#   'location': 'Bloodhound',
#   'street': 'FOLSOM',
#   'placement': 'SIDEWALK',
#   'racks': '2',
#   'spaces': '4',
#   'globalid': '{C0868CE8-923E-46BF-8394-5CE5D708DD5F}',
#   'lat': '37.775865',
#   'lon': '-122.408835',
#   'point': {'type': 'Point',
#    'coordinates': [-122.40883522803117, 37.77586467326873]}},
#  {'install_yr': '2013',
#   'install_mo': '9',
#   'objectid': '865',
#   'address': '5 MASONIC AVE',
#   'location': 'Corner Store',
#   'street': 'MASONIC',
#   'placement': 'SIDEWALK',
#   'racks': '2',
#   'spaces': '4',
#   'globalid': '{B6B87085-D37B-4E16-B8BF-5215AD8FC1F1}',
#   'lat': '37.782082',
#   'lon': '-122.448003',
#   'point': {'type': 'Point',
#    'coordinates': [-122.44800278838544, 37.78208200505725]}},
#  {'install_yr': '2009',
#   'install_mo': '0',
#   'objectid': '2067',
#   'address': '159 LELAND AVE',
#   'location': 'UNKNOWN',
#   'street': 'LELAND',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{67427B5A-2200-4833-839C-382A013EB2F3}',
#   'lat': '37.712172',
#   'lon': '-122.406887',
#   'point': {'type': 'Point',
#    'coordinates': [-122.40688680269643, 37.712172008202565]}},
#  {'install_yr': '2015',
#   'install_mo': '11',
#   'objectid': '2301',
#   'address': '2550 MISSION ST',
#   'location': 'Alamo Draft House',
#   'street': 'MISSION',
#   'placement': 'ROADWAY',
#   'racks': '6',
#   'spaces': '12',
#   'globalid': '{C87FC4FD-AC76-46C4-AA36-8130939C14C4}',
#   'lat': '37.756216',
#   'lon': '-122.418909',
#   'point': {'type': 'Point',
#    'coordinates': [-122.41890905538473, 37.75621561851474]}},
#  {'install_yr': '2003',
#   'install_mo': '0',
#   'objectid': '1364',
#   'address': '621 DIVISADERO ST',
#   'location': 'Divisadero Health Haven',
#   'street': 'DIVISADERO',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{FA3D5193-1A60-4D7F-A18A-8052504292B7}',
#   'lat': '37.775317',
#   'lon': '-122.438032',
#   'point': {'type': 'Point',
#    'coordinates': [-122.43803179062189, 37.77531700450891]}},
#  {'install_yr': '2012',
#   'install_mo': '2',
#   'objectid': '768',
#   'address': '2576 HARRISON ST',
#   'location': 'Moscone Elementry',
#   'street': 'HARRISON',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{B13418DF-5A0F-4C3A-AB08-7E437C87E736}',
#   'lat': '37.756822',
#   'lon': '-122.412738',
#   'point': {'type': 'Point',
#    'coordinates': [-122.41273749712231, 37.75682184477724]}},
#  {'install_yr': '2013',
#   'install_mo': '1',
#   'objectid': '2652',
#   'address': '800 HOWARD ST',
#   'location': 'Moscone West',
#   'street': 'HOWARD',
#   'placement': 'SIDEWALK',
#   'racks': '3',
#   'spaces': '6',
#   'globalid': '{6881671C-F7BA-452B-B59E-7A249A8A19A6}',
#   'lat': '37.782915',
#   'lon': '-122.404861',
#   'point': {'type': 'Point',
#    'coordinates': [-122.40486079506908, 37.78291500176194]}},
#  {'install_yr': '2017',
#   'install_mo': '2',
#   'objectid': '3299',
#   'address': '2230 Polk',
#   'location': 'Russian Hill Bookstore',
#   'street': 'POLK',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{1E41FCEB-B84C-4255-B375-53D19A4EAC2E}',
#   'lat': '37.797257',
#   'lon': '-122.421945',
#   'point': {'type': 'Point',
#    'coordinates': [-122.42194537980164, 37.797256723537174]}},
#  {'install_yr': '2003',
#   'install_mo': '0',
#   'objectid': '2389',
#   'address': '36 02ND ST',
#   'location': 'UNKNOWN',
#   'street': '02ND',
#   'placement': 'SIDEWALK',
#   'racks': '2',
#   'spaces': '4',
#   'globalid': '{BD597E41-E040-47FE-A8B6-E812541DCE9B}',
#   'lat': '37.788582',
#   'lon': '-122.400945',
#   'point': {'type': 'Point',
#    'coordinates': [-122.40094479542081, 37.7885820020225]}},
#  {'install_yr': '2003',
#   'install_mo': '0',
#   'objectid': '54',
#   'address': '312 MASON ST',
#   'location': 'UNKNOWN',
#   'street': 'MASON',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{1DBF7269-3D7B-4BDF-A28F-CD9B3B04DCD3}',
#   'lat': '37.786495',
#   'lon': '-122.409504',
#   'point': {'type': 'Point',
#    'coordinates': [-122.40950379406557, 37.78649500216531]}},
#  {'install_yr': '2009',
#   'install_mo': '0',
#   'objectid': '740',
#   'address': '96 LELAND AVE',
#   'location': 'El Buen Saborz',
#   'street': 'LELAND',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{EF63DAB4-B9A4-44E8-9A00-2747DFD886C5}',
#   'lat': '37.712065',
#   'lon': '-122.405342',
#   'point': {'type': 'Point',
#    'coordinates': [-122.40534180316766, 37.71206500817565]}},
#  {'install_yr': '2013',
#   'install_mo': '5',
#   'objectid': '2357',
#   'address': '2001 POLK ST',
#   'location': 'Cheese Plus',
#   'street': 'POLK',
#   'placement': 'SIDEWALK',
#   'racks': '2',
#   'spaces': '4',
#   'globalid': '{855415BB-7549-48E2-9825-E5AE31B407F6}',
#   'lat': '37.795225',
#   'lon': '-122.421819',
#   'point': {'type': 'Point',
#    'coordinates': [-122.42181879101184, 37.79522500233863]}},
#  {'install_yr': '2010',
#   'install_mo': '0',
#   'objectid': '1632',
#   'address': '286 DIVISADERO ST',
#   'location': 'Yoga Garden of San Francisco',
# ...
#   'point': {'type': 'Point',
#    'coordinates': [-122.4172402940731, 37.77583213360202]}},
#  {'install_yr': '2002',
#   'install_mo': '0',
#   'objectid': '1727',
#   'address': '400 CORTLAND AVE',
#   'location': 'Progressive Grounds',
#   'street': 'CORTLAND',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{F8F87009-3D21-456A-8355-71755212B945}',
#   'lat': '37.738948',
#   'lon': '-122.417673',
#   'point': {'type': 'Point',
#    'coordinates': [-122.41767279748879, 37.73894800635931]}},
#  {'install_yr': '2004',
#   'install_mo': '0',
#   'objectid': '1286',
#   'address': '3100 16TH ST',
#   'location': 'Val 16 Market',
#   'street': '16TH',
#   'placement': 'SIDEWALK',
#   'racks': '2',
#   'spaces': '4',
#   'globalid': '{2C311E65-0B12-434C-988B-49BF0838F0ED}',
#   'lat': '37.765134',
#   'lon': '-122.42222',
#   'point': {'type': 'Point',
#    'coordinates': [-122.42221969440513, 37.765134445423854]}},
#  {'install_yr': '2013',
#   'install_mo': '1',
#   'objectid': '1042',
#   'address': '818 MISSION ST',
#   'location': 'Community Vocational Enterprises',
#   'street': 'MISSION',
#   'placement': 'SIDEWALK',
#   'racks': '2',
#   'spaces': '4',
#   'globalid': '{AEAA617A-748F-4608-B3A0-90B892419BBC}',
#   'lat': '37.784291',
#   'lon': '-122.40507',
#   'point': {'type': 'Point',
#    'coordinates': [-122.40506979423446, 37.784291001423114]}},
#  {'install_yr': '2003',
#   'install_mo': '0',
#   'objectid': '1165',
#   'address': '2319 MARKET ST',
#   'location': 'Wingard Kenneth',
#   'street': 'MARKET',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{7CC9AB54-7019-4F71-8944-2136FD2E2980}',
#   'lat': '37.763339',
#   'lon': '-122.433614',
#   'point': {'type': 'Point',
#    'coordinates': [-122.43361379230402, 37.76333900532745]}},
#  {'install_yr': '2016',
#   'install_mo': '10',
#   'objectid': '3353',
#   'address': '3951 Balboa',
#   'location': 'CVC',
#   'street': 'BALBOA',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{635F5148-05EE-4600-8C03-9B1578FC4DED}',
#   'lat': '37.775476',
#   'lon': '-122.501062',
#   'point': {'type': 'Point',
#    'coordinates': [-122.50106199130336, 37.77547552283318]}},
#  {'install_yr': '0',
#   'install_mo': '0',
#   'objectid': '2167',
#   'address': '1271 TREAT AVE',
#   'location': 'Garfield Square',
#   'street': 'HARRISON',
#   'placement': 'SIDEWALK',
#   'racks': '2',
#   'spaces': '4',
#   'globalid': '{F2CA1F55-B506-444D-A6C4-525B2AC3E108}',
#   'lat': '37.750196',
#   'lon': '-122.412222',
#   'point': {'type': 'Point',
#    'coordinates': [-122.41222239726156, 37.750195585030426]}},
#  {'install_yr': '2010',
#   'install_mo': '10',
#   'objectid': '2621',
#   'address': '3471 MISSION ST',
#   'location': 'Angkor Borei',
#   'street': 'MISSION',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{F5924DA4-1066-4887-92B1-0E2139CA1AA9}',
#   'lat': '37.741198',
#   'lon': '-122.422329',
#   'point': {'type': 'Point',
#    'coordinates': [-122.42232879689865, 37.741198006762716]}},
#  {'install_yr': '2012',
#   'install_mo': '7',
#   'objectid': '2661',
#   'address': '696 VALENCIA ST',
#   'location': 'F.S.C Barber',
#   'street': 'VALENCIA',
#   'placement': 'SIDEWALK',
#   'racks': '2',
#   'spaces': '4',
#   'globalid': '{180F0B31-DD9C-468E-8BB5-D4BF6835EE48}',
#   'lat': '37.761808',
#   'lon': '-122.421893',
#   'point': {'type': 'Point',
#    'coordinates': [-122.42189279421208, 37.761808004876556]}},
#  {'install_yr': '2012',
#   'install_mo': '10',
#   'objectid': '622',
#   'address': '1398 SOUTH VAN NESS AVE',
#   'location': 'Phone Booth Bar',
#   'street': 'S VAN NESS',
#   'placement': 'SIDEWALK',
#   'racks': '3',
#   'spaces': '6',
#   'globalid': '{89C713D5-02E2-4C11-BDF2-1BCCEF722EF2}',
#   'lat': '37.750866',
#   'lon': '-122.416446',
#   'point': {'type': 'Point',
#    'coordinates': [-122.41644579616356, 37.75086600618274]}},
#  {'install_yr': '2012',
#   'install_mo': '7',
#   'objectid': '305',
#   'address': '2415 17TH ST',
#   'location': 'ASN Natural Stone',
#   'street': '17TH',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{32C1B798-4ABC-49B2-A161-250C9F9B37D7}',
#   'lat': '37.764151',
#   'lon': '-122.407897',
#   'point': {'type': 'Point',
#    'coordinates': [-122.40789679692713, 37.76415100380771]}},
#  {'install_yr': '2016',
#   'install_mo': '7',
#   'objectid': '3551',
#   'address': '1300 Sanchez Street',
#   'location': 'The ROOT',
#   'street': 'SANCHEZ',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{A63D7021-E94B-4037-98D5-D420F5C49A6D}',
#   'lat': '37.748333',
#   'lon': '-122.42943',
#   'point': {'type': 'Point',
#    'coordinates': [-122.42943042402227, 37.74833311935751]}},
#  {'install_yr': '0',
#   'install_mo': '0',
#   'objectid': '770',
#   'address': '159 LINDA ST',
#   'location': 'Mission Pool',
#   'street': 'LINDA',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{975EDA6B-CD0C-4838-8CE6-F7EEE396287C}',
#   'lat': '37.7593',
#   'lon': '-122.422374',
#   'point': {'type': 'Point',
#    'coordinates': [-122.42237429472645, 37.759299845453725]}},
#  {'install_yr': '2007',
#   'install_mo': '0',
#   'objectid': '412',
#   'address': '310 BERRY ST',
#   'location': 'Intracorp San Francisco',
#   'street': 'BERRY',
#   'placement': 'SIDEWALK',
#   'racks': '3',
#   'spaces': '3',
#   'globalid': '{09D246F0-F8F4-44BC-B1DD-5AF621493C2E}',
#   'lat': '37.773925',
#   'lon': '-122.396228',
#   'point': {'type': 'Point',
#    'coordinates': [-122.39622779700015, 37.77392500254464]}},
#  {'install_yr': '2010',
#   'install_mo': '0',
#   'objectid': '1817',
#   'address': '2575 OCEAN AVE',
#   'location': 'World Team Kickboxing',
#   'street': 'OCEAN',
#   'placement': 'SIDEWALK',
#   'racks': '2',
#   'spaces': '4',
#   'globalid': '{096317CD-8F25-410A-A1AC-C192EC7AC67F}',
#   'lat': '37.731439',
#   'lon': '-122.473324',
#   'point': {'type': 'Point',
#    'coordinates': [-122.47332379116814, 37.7314390118137]}},
#  {'install_yr': '0',
#   'install_mo': '0',
#   'objectid': '2138',
#   'address': '3980 24TH ST',
#   'location': 'Green 11',
#   'street': '24TH',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{4087BE1B-5ED0-404A-8ABA-9AC5A5FB5304}',
#   'lat': '37.751693',
#   'lon': '-122.431431',
#   'point': {'type': 'Point',
#    'coordinates': [-122.43143079433544, 37.75169259646299]}},
#  {'install_yr': '2010',
#   'install_mo': '5',
#   'objectid': '2441',
#   'address': '1299 VALENCIA ST',
#   'location': "Valencia Farmer's Market",
#   'street': 'VALENCIA',
#   'placement': 'ROADWAY',
#   'racks': '4',
#   'spaces': '8',
#   'globalid': '{423BDCA0-C0B7-4459-989A-3D801CC14985}',
#   'lat': '37.752242',
#   'lon': '-122.420361',
#   'point': {'type': 'Point',
#    'coordinates': [-122.42036109667018, 37.75224185602273]}},
#  {'install_yr': '2012',
#   'install_mo': '8',
#   'objectid': '2298',
#   'address': '1714 HAYES ST',
#   'location': 'Chop Shop',
#   'street': 'HAYES',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{50134DE2-A7F7-4DE1-8102-22941A3D963E}',
#   'lat': '37.774261',
#   'lon': '-122.444656',
#   'point': {'type': 'Point',
#    'coordinates': [-122.44465579058425, 37.774261005517424]}},
#  {'install_yr': '2005',
#   'install_mo': '0',
#   'objectid': '2030',
#   'address': '1546 GUERRERO ST',
#   'location': 'UNKNOWN',
#   'street': 'GUERRERO',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{B30427A6-9CE0-435A-B263-DF1AFC6CC088}',
#   'lat': '37.746478',
#   'lon': '-122.42265',
#   'point': {'type': 'Point',
#    'coordinates': [-122.42264979626954, 37.74647800643934]}},
#  {'install_yr': '2016',
#   'install_mo': '11',
#   'objectid': '3368',
#   'address': '441 Clement',
#   'location': 'The Bitter End',
#   'street': 'CLEMENT',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{A2F9C1C7-AA4F-4021-A1A3-5D129B97E0B7}',
#   'lat': '37.7829',
#   'lon': '-122.46379',
#   'point': {'type': 'Point',
#    'coordinates': [-122.46379002766898, 37.78290027916205]}},
#  {'install_yr': '2010',
#   'install_mo': '11',
#   'objectid': '939',
#   'address': '3989 17TH ST',
#   'location': 'Wild Card',
#   'street': '17TH',
#   'placement': 'SIDEWALK',
#   'racks': '2',
#   'spaces': '4',
#   'globalid': '{846B5DBB-FFE9-44CA-88AA-761338A990B4}',
#   'lat': '37.762278',
#   'lon': '-122.434767',
#   'point': {'type': 'Point',
#    'coordinates': [-122.43476699259105, 37.76227818552539]}},
#  {'install_yr': '2015',
#   'install_mo': '1',
#   'objectid': '1393',
#   'address': '524 IRVING ST',
#   'location': 'Loving Hut',
#   'street': 'IRVING',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{F0903C74-62DC-4A1C-93E5-2FAA9D61124C}',
#   'lat': '37.764315',
#   'lon': '-122.463587',
#   'point': {'type': 'Point',
#    'coordinates': [-122.46358678715728, 37.76431500757097]}},
#  {'install_yr': '2012',
#   'install_mo': '7',
#   'objectid': '2014',
#   'address': '4245 LAWTON ST',
#   'location': 'Sunset Co-op Nursery School',
#   'street': 'LAWTON',
#   'placement': 'SIDEWALK',
#   'racks': '4',
#   'spaces': '8',
#   'globalid': '{A2B3140C-59FE-49B8-A00E-582933AF6288}',
#   'lat': '37.756379',
#   'lon': '-122.50849',
#   'point': {'type': 'Point',
#    'coordinates': [-122.50848978314423, 37.75637901207934]}},
#  {'install_yr': '2011',
#   'install_mo': '1',
#   'objectid': '97',
#   'address': '625 DOUGLASS ST',
#   'location': 'Alvarado Elementary School',
#   'street': 'DOUGLASS',
#   'placement': 'SIDEWALK',
#   'racks': '3',
#   'spaces': '6',
#   'globalid': '{A886C1F7-7E75-4576-8E00-314110294495}',
#   'lat': '37.753677',
#   'lon': '-122.43818',
#   'point': {'type': 'Point',
#    'coordinates': [-122.43817979294253, 37.75367700724266]}},
#  {'install_yr': '2015',
#   'install_mo': '1',
#   'objectid': '1053',
#   'address': '4520 MISSION ST',
#   'location': 'The Wash Palace',
#   'street': 'MISSION',
#   'placement': 'SIDEWALK',
#   'racks': '2',
#   'spaces': '4',
#   'globalid': '{4C04E213-80CE-4FF8-930E-626CD2DD6E3C}',
#   'lat': '37.725632',
#   'lon': '-122.43443',
#   'point': {'type': 'Point',
#    'coordinates': [-122.43443039699847, 37.72563160854851]}},
#  {'install_yr': '2015',
#   'install_mo': '11',
#   'objectid': '2469',
#   'address': '1400-1598 John F Kennedy Dr.',
#   'location': 'Beach Chalet Athletic Fields - Golden Gate Park',
#   'street': 'JOHN F KENNEDY',
#   'placement': 'PARCEL',
#   'racks': '38',
#   'spaces': '76',
#   'globalid': '{5595F152-607C-4730-A007-B88FFE71EEFF}',
#   'lat': '37.770731',
#   'lon': '-122.492551',
#   'point': {'type': 'Point',
#    'coordinates': [-122.49255087560209, 37.770730792992616]}},
#  {'install_yr': '2006',
#   'install_mo': '0',
#   'objectid': '984',
#   'address': '248 CHURCH ST',
#   'location': 'Thorough Bread& Pastry',
#   'street': 'CHURCH',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{228E7B11-F8B9-451A-8FEB-B1C7B25196BC}',
#   'lat': '37.766623',
#   'lon': '-122.429128',
#   'point': {'type': 'Point',
#    'coordinates': [-122.42912779266763, 37.76662300528482]}},
#  {'install_yr': '0',
#   'install_mo': '0',
#   'objectid': '1196',
#   'address': '900 VALENCIA ST',
#   'location': 'Dog Eared Books',
#   'street': '20TH',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{ED9AD673-6770-44A2-A73C-E04ED1BEEB2F}',
#   'lat': '37.75825',
#   'lon': '-122.421507',
#   'point': {'type': 'Point',
#    'coordinates': [-122.42150709496718, 37.75824974559136]}},
#  {'install_yr': '2006',
#   'install_mo': '0',
#   'objectid': '2615',
#   'address': '79 NEW MONTGOMERY ST',
#   'location': 'Academy of Art University',
#   'street': 'NEW MONTGOMERY',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{0C1B8053-EB3C-4DDA-9397-F13D099F8332}',
#   'lat': '37.787885',
#   'lon': '-122.400522',
#   'point': {'type': 'Point',
#    'coordinates': [-122.40052179472934, 37.78788500176135]}},
#  {'install_yr': '2005',
#   'install_mo': '0',
#   'objectid': '1855',
#   'address': '600 16TH ST',
#   'location': 'UCSF Mission Bay Genentech Hall',
#   'street': 'CAMPUS LANE',
#   'placement': 'PARCEL',
#   'racks': '48',
#   'spaces': '48',
#   'globalid': '{00CE3486-94D1-4F7F-808D-1C38508369D6}',
#   'lat': '37.767625',
#   'lon': '-122.392397',
#   'point': {'type': 'Point',
#    'coordinates': [-122.39239679936306, 37.76762500204092]}},
#  {'install_yr': '2010',
#   'install_mo': '0',
#   'objectid': '630',
#   'address': '3639 TARAVAL ST',
#   'location': 'Riptide Bar',
#   'street': '47TH',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{7BF21D07-C5ED-4AE8-990F-5116C213F5CE}',
#   'lat': '37.741567',
#   'lon': '-122.505313',
#   'point': {'type': 'Point',
#    'coordinates': [-122.50531278510893, 37.74156701278212]}},
#  {'install_yr': '2002',
#   'install_mo': '0',
#   'objectid': '2189',
#   'address': '1650 VALENCIA ST',
#   'location': 'medical building',
#   'street': 'VALENCIA',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{21FBA037-C057-4051-99EA-90CE6349D188}',
#   'lat': '37.746152',
#   'lon': '-122.420315',
#   'point': {'type': 'Point',
#    'coordinates': [-122.42031479678899, 37.74615200588595]}},
#  {'install_yr': '2004',
#   'install_mo': '0',
#   'objectid': '801',
#   'address': '125 GRANT AVE',
#   'location': 'Hermes',
#   'street': 'GRANT',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{29DE0301-A5D8-474D-82CF-51722956CC69}',
#   'lat': '37.788072',
#   'lon': '-122.405341',
#   'point': {'type': 'Point',
#    'coordinates': [-122.40534079488735, 37.78807200116046]}},
#  {'install_yr': '2017',
#   'install_mo': '2',
#   'objectid': '3302',
#   'address': '2435 Polk',
#   'location': 'Cocoon Bare',
#   'street': 'POLK',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{C53762E6-635E-41FA-817F-EA39738DCF2A}',
#   'lat': '37.799083',
#   'lon': '-122.422489',
#   'point': {'type': 'Point',
#    'coordinates': [-122.42248943226086, 37.799082653412796]}},
#  {'install_yr': '2015',
#   'install_mo': '1',
#   'objectid': '2852',
#   'address': '2345 HARRISON ST',
#   'location': 'HIT Fit SF',
#   'street': 'HARRISON',
#   'placement': 'SIDEWALK',
#   'racks': '2',
#   'spaces': '4',
#   'globalid': '{D5D38269-7406-489D-B513-DCB46CF55D7C}',
#   'lat': '37.759818',
#   'lon': '-122.412331',
#   'point': {'type': 'Point',
#    'coordinates': [-122.41233109550997, 37.75981750383322]}},
#  {'install_yr': '2002',
#   'install_mo': '0',
#   'objectid': '2633',
#   'address': '518 VALENCIA ST',
#   'location': 'Abandoned Planet bookstore',
#   'street': 'VALENCIA',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{CFEE3664-DADA-4C23-B422-E387389B4439}',
#   'lat': '37.764492',
#   'lon': '-122.422131',
#   'point': {'type': 'Point',
#    'coordinates': [-122.42213079371382, 37.76449200535059]}},
#  {'install_yr': '2003',
#   'install_mo': '0',
#   'objectid': '1370',
#   'address': '583 HAIGHT ST',
#   'location': 'UNKNOWN',
#   'street': 'HAIGHT',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{E9FDD948-BA16-44C4-8CC0-7B66CD836F16}',
#   'lat': '37.771791',
#   'lon': '-122.431706',
#   'point': {'type': 'Point',
#    'coordinates': [-122.43170579214106, 37.77179100422077]}},
#  {'install_yr': '2012',
#   'install_mo': '2',
#   'objectid': '387',
#   'address': '2937 24TH ST',
#   'location': 'la Victoria Bakery',
#   'street': '24TH',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{1D1D8488-A8B1-443D-B84E-223D716AB1AE}',
#   'lat': '37.752515',
#   'lon': '-122.410743',
#   'point': {'type': 'Point',
#    'coordinates': [-122.41074279645997, 37.752515004744566]}},
#  {'install_yr': '2013',
#   'install_mo': '6',
#   'objectid': '2473',
#   'address': '3026 24TH ST',
#   'location': 'Liberty Tax',
#   'street': '24TH',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{5045921D-4BBA-4B55-A574-5489B16C2F7E}',
#   'lat': '37.752819',
#   'lon': '-122.412514',
#   'point': {'type': 'Point',
#    'coordinates': [-122.41251379645375, 37.75281900519196]}},
#  {'install_yr': '2013',
#   'install_mo': '11',
#   'objectid': '316',
#   'address': '414 BRANNAN ST',
#   'location': 'Hattery',
#   'street': 'BRANNAN',
#   'placement': 'SIDEWALK',
#   'racks': '1',
#   'spaces': '2',
#   'globalid': '{35DEC836-044E-41E4-AA00-AD55DDE3C75F}',
#   'lat': '37.779926',
#   'lon': '-122.394855',
#   'point': {'type': 'Point',
#    'coordinates': [-122.39485529648906, 37.77992578188656]}}]

# %%
# turn the json data into a dataframe
df = pd.DataFrame(data)
df.head()
# Out:
#   install_yr install_mo objectid         address               location  \
# 0       2010          9      647  1631 OCEAN AVE                   NCPS
# 1       2004          0     1960    3913 24TH ST                  Savor
# 2       2005          0     2643     428 03RD ST     Rayko Photo Center
# 3       2004          0     1108     265 KING ST  Avalon at Mission Bay
# 4       2016          8     3391    1552 polk st            Common Sage
#
#   street placement racks spaces                                globalid  \
# 0  OCEAN  SIDEWALK     1      2  {7337F39A-EBBA-43C1-A5C0-296571D141B7}
# 1   24TH  SIDEWALK     1      2  {57C56DCE-DE09-462E-B190-0B2A34539F3C}
# 2   03RD  SIDEWALK     2      4  {90BEBAAB-89ED-4620-8588-6414835E11B3}
# 3   KING  SIDEWALK     3      3  {F76F49F0-E98E-4C69-A14C-6E7CE10D6D76}
# 4   POLK  SIDEWALK     3      6  {E2266A03-A979-48A1-ACF4-6BDEDCAC6B61}
#
#          lat          lon                                              point
# 0  37.724406  -122.459797  {'type': 'Point', 'coordinates': [-122.4597967...
# 1  37.751288  -122.430024  {'type': 'Point', 'coordinates': [-122.4300237...
# 2  37.781964  -122.397278  {'type': 'Point', 'coordinates': [-122.3972777...
# 3  37.776211  -122.393931  {'type': 'Point', 'coordinates': [-122.3939307...
# 4  37.791074    -122.4207  {'type': 'Point', 'coordinates': [-122.4207002...

# %%
# this column contains dicts that contain lats and lons
df['point'][1]
# Out:
# {'type': 'Point', 'coordinates': [-122.43002379492016, 37.75128800595019]}

# %%
# create lists to hold all my lat-lons as i extract them
latitudes = []
longitudes = []

# loop through each row in df, extracting lat and lon values if geom is not null
for label, row in df.iterrows():
    if pd.notnull(row['point']):
        latitudes.append(row['point']['coordinates'][1])
        longitudes.append(row['point']['coordinates'][0])
    else:
        latitudes.append(None)
        longitudes.append(None)

# %%
df['lat'] = latitudes
df['lon'] = longitudes

# %%
df2 = df[['lat', 'lon']]
df2.head()
# Out:
#          lat         lon
# 0  37.724406 -122.459797
# 1  37.751288 -122.430024
# 2  37.781964 -122.397278
# 3  37.776211 -122.393931
# 4  37.791074 -122.420700

# %%
df2.iterrows
# Out:
# <bound method DataFrame.iterrows of            lat         lon
# 0    37.724406 -122.459797
# 1    37.751288 -122.430024
# 2    37.781964 -122.397278
# 3    37.776211 -122.393931
# 4    37.791074 -122.420700
# ..         ...         ...
# 995  37.764492 -122.422131
# 996  37.771791 -122.431706
# 997  37.752515 -122.410743
# 998  37.752819 -122.412514
# 999  37.779926 -122.394855
#
# [1000 rows x 2 columns]>

# %%
f_map = folium.Map(location=[37.75, -122.45], tiles="Stamen Toner", control_scale=True, zoom_start=12)
for ix, row in df2.iterrows():
    folium.Marker([row['lat'], row['lon']]).add_to(f_map)

# %%
f_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
